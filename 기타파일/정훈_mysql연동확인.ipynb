# %%
import mysql.connector as mysql

# %%
import json

with open("test_json.json","r") as f:
    input = f.read()

# %%
test=json.loads(input)

# %%
test
# Out:
# {'host': 'lunch-lab-db.c7gaq8m06dlk.ap-southeast-2.rds.amazonaws.com',
#  'port': 3306,
#  'user': 'admin',
#  'password': 'lunchlab0219'}

# %%
test_connect=mysql.connect(**test)

# %%
corr=test_connect.cursor()

# %%
corr.execute("show databases")
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 corr.execute("show databases")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/mysql/connector/cursor_cext.py:347, in CMySQLCursor.execute(self, operation, params, multi)
#     345 except (ProgrammingError, ReferenceError) as err:
#     346     raise ProgrammingError("Cursor is not connected", 2055) from err
# --> 347 self._cnx.handle_unread_result()
#     349 stmt = b""
#     350 self.reset()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/mysql/connector/connection_cext.py:990, in CMySQLConnection.handle_unread_result(self, prepared)
#     988     self.consume_results()
#     989 elif unread_result:
# --> 990     raise InternalError("Unread result found")
#
# InternalError: Unread result found

# %%
corr.fetchall()
# Out:
# [('ORIGINAL',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',),
#  ('test',)]
